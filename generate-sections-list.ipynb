# %%
from bs4 import BeautifulSoup

# %%
html = open('cl-homepage.html')
parsed = BeautifulSoup(html, "lxml")

# %%
sections = parsed.findAll('div',{'class':'cats'})
for section in sections:
    print "\n"
    for x in section.findAll('a'):
        try:
            print '"'+x.text+'":"'+x['data-cat']+'",'
        except:
            continue
# Out:
# "activities":"act",
# "artists":"ats",
# "childcare":"kid",
# "classes":"cls",
# "events":"eve",
# "general":"com",
# "groups":"grp",
# "local news":"vnn",
# "lost+found":"laf",
# "musicians":"muc",
# "pets":"pet",
# "politics":"pol",
# "rideshare":"rid",
# "volunteers":"vol",
#
#
# "strictly platonic":"stp",
# "women seek women":"w4w",
# "women seeking men":"w4m",
# "men seeking women":"m4w",
# "men seeking men":"m4m",
# "misc romance":"msr",
# "casual encounters":"cas",
# "missed connections":"mis",
# "rants and raves":"rnr",
#
#
#
#
# "apts / housing":"apa",
# "housing swap":"swp",
# "housing wanted":"hsw",
# "office / commercial":"off",
# "parking / storage":"prk",
# "real estate for sale":"rea",
# "rooms / shared":"roo",
# "rooms wanted":"sha",
# "sublets / temporary":"sub",
# "vacation rentals":"vac",
#
#
# "antiques":"ata",
# "appliances":"ppa",
# "arts+crafts":"ara",
# "atv/utv/sno":"sna",
# "auto parts":"pta wta",
# "baby+kid":"baa",
# "barter":"bar",
# "beauty+hlth":"haa",
# ...
